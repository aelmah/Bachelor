# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 1

# %%
df = pd.read_csv("data/Crimes_2012-2016.csv",index_col='Date.Rptd',parse_dates=['Date.Rptd'])
df
# Out:
#                 DR.NO    DATE.OCC  TIME.OCC  AREA    AREA.NAME    RD  Crm.Cd  \
# Date.Rptd
# 2013-03-20  132007717  03/20/2013      2015    20      Olympic  2004     997
# 2013-03-10  130608787  03/10/2013       445     6    Hollywood   635     997
# 2013-12-18  131820260  12/18/2013       745    18    Southeast  1839     997
# 2013-10-18  131817514  10/18/2013      1730    18    Southeast  1827     997
# 2013-05-26  130510483  05/25/2013      2000     5       Harbor   507     440
# ...               ...         ...       ...   ...          ...   ...     ...
# 2016-05-01  162010003  04/30/2016      2200    20      Olympic  2069     740
# 2016-06-29  160315990  06/29/2016      1020     3    Southwest   353     946
# 2016-05-01  161200696  05/01/2016      2030    12  77th Street  1256     626
# 2016-09-05  161015111  09/05/2016       800    10  West Valley  1017     440
# 2016-11-27  161228506  11/27/2016      1855    12  77th Street  1207     510
#
# ...

# %% [markdown]
# # 2

# %%
df.isna().count()
# Out:
# DR.NO           1136589
# DATE.OCC        1136589
# TIME.OCC        1136589
# AREA            1136589
# AREA.NAME       1136589
# RD              1136589
# Crm.Cd          1136589
# CrmCd.Desc      1136589
# Status          1136589
# Status.Desc     1136589
# LOCATION        1136589
# Cross.Street    1136589
# Location.1      1136589
# dtype: int64

# %%
df.dropna()
# Out:
#                 DR.NO    DATE.OCC  TIME.OCC  AREA    AREA.NAME    RD  Crm.Cd  \
# Date.Rptd
# 2013-03-20  132007717  03/20/2013      2015    20      Olympic  2004     997
# 2013-03-10  130608787  03/10/2013       445     6    Hollywood   635     997
# 2013-12-18  131820260  12/18/2013       745    18    Southeast  1839     997
# 2013-10-18  131817514  10/18/2013      1730    18    Southeast  1827     997
# 2013-05-24  131213618  05/22/2013      1145    12  77th Street  1211     997
# ...               ...         ...       ...   ...          ...   ...     ...
# 2016-06-19  161314121  06/19/2016      2330    13       Newton  1395     220
# 2016-04-12  161809182  04/12/2016      1100    18    Southeast  1821     210
# 2016-07-06  162013236  07/06/2016      1900    20      Olympic  2029     626
# 2016-05-07  160709516  05/07/2016      1115     7     Wilshire   701     624
# 2016-02-28  160506504  02/28/2016      2110     5       Harbor   519     438
#
# ...

# %% [markdown]
# # 3

# %%
df.duplicated()
# Out:
# Date.Rptd
# 2013-03-20    False
# 2013-03-10    False
# 2013-12-18    False
# 2013-10-18    False
# 2013-05-26    False
#               ...
# 2016-05-01    False
# 2016-06-29    False
# 2016-05-01    False
# 2016-09-05    False
# 2016-11-27    False
# Length: 1136589, dtype: bool

# %%
df.drop_duplicates()
# Out:
#                 DR.NO    DATE.OCC  TIME.OCC  AREA    AREA.NAME    RD  Crm.Cd  \
# Date.Rptd
# 2013-03-20  132007717  03/20/2013      2015    20      Olympic  2004     997
# 2013-03-10  130608787  03/10/2013       445     6    Hollywood   635     997
# 2013-12-18  131820260  12/18/2013       745    18    Southeast  1839     997
# 2013-10-18  131817514  10/18/2013      1730    18    Southeast  1827     997
# 2013-05-26  130510483  05/25/2013      2000     5       Harbor   507     440
# ...               ...         ...       ...   ...          ...   ...     ...
# 2016-05-01  162010003  04/30/2016      2200    20      Olympic  2069     740
# 2016-06-29  160315990  06/29/2016      1020     3    Southwest   353     946
# 2016-05-01  161200696  05/01/2016      2030    12  77th Street  1256     626
# 2016-09-05  161015111  09/05/2016       800    10  West Valley  1017     440
# 2016-11-27  161228506  11/27/2016      1855    12  77th Street  1207     510
#
# ...

# %% [markdown]
# # 4

# %%
df.describe()
# Out:
#               DR.NO      TIME.OCC          AREA            RD        Crm.Cd
# count  1.136589e+06  1.136589e+06  1.136589e+06  1.136589e+06  1.136589e+06
# mean   1.405451e+08  1.367056e+03  1.109752e+01  1.156037e+03  5.798710e+02
# std    1.389175e+07  6.374626e+02  5.982122e+00  5.983798e+02  2.593059e+02
# min    4.180000e+02  1.000000e+00  1.000000e+00  1.000000e+02  1.100000e+02
# 25%    1.306055e+08  9.300000e+02  6.000000e+00  6.450000e+02  3.410000e+02
# 50%    1.410093e+08  1.430000e+03  1.100000e+01  1.181000e+03  5.100000e+02
# 75%    1.514123e+08  1.900000e+03  1.600000e+01  1.664000e+03  7.450000e+02
# max    1.699148e+08  2.359000e+03  2.100000e+01  2.198000e+03  9.970000e+02

# %% [markdown]
# # 5

# %%
df.shape
# Out:
# (1136589, 13)

# %% [markdown]
# # 6

# %%
df['AREA.NAME'].unique()
# Out:
# array(['Olympic', 'Hollywood', 'Southeast', 'Harbor', '77th Street',
#        'Central', 'Van Nuys', 'Newton', 'Topanga', 'Foothill',
#        'Northeast', 'Southwest', 'West LA', 'Mission', 'West Valley',
#        'Rampart', 'Hollenbeck', 'Devonshire', 'Pacific', 'N Hollywood',
#        'Wilshire'], dtype=object)

# %% [markdown]
# # 7

# %%
df['DATE.OCC'] = pd.to_datetime(df['DATE.OCC'])
df['Year'] = df['DATE.OCC'].dt.year
crimeParAns = df['Year'].value_counts()
crimeParAns = crimeParAns.sort_index()
sns.lineplot(crimeParAns)
plt.show()

# %% [markdown]
# # 8

# %%
top_10_crimes = df['CrmCd.Desc'].value_counts().nlargest(10)
sns.barplot(x = top_10_crimes.index,y = top_10_crimes.values,palette='Set1',hue=top_10_crimes.index)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # 9

# %%
top_10_AreaName = df['AREA.NAME'].value_counts().head(10)
sns.barplot(x = top_10_AreaName.index,y = top_10_AreaName.values,palette='Set2',hue=top_10_AreaName.index)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # 10

# %%
print("Zone avec le taux de mortalité le plus elever")
print(df['AREA.NAME'].value_counts().head(1))
# Out:
# Zone avec le taux de mortalité le plus elever
# AREA.NAME
# 77th Street    77928
# Name: count, dtype: int64

# %% [markdown]
# # 11

# %%
df['DATE.OCC'] = pd.to_datetime(df['DATE.OCC'])
crimes_southwest = df[(df['DATE.OCC'].dt.year >= 2012) 
                      & (df['DATE.OCC'].dt.year <= 2015) 
                      & (df['AREA.NAME'] == 'Southwest')]
print("total des crimes : ",len(crimes_southwest))
# Out:
# total des crimes :  60191

# %% [markdown]
# # 12

# %%
crimes_southwest = df[df['AREA.NAME'] == 'Southwest']
top_30_crimes_southwest = crimes_southwest['CrmCd.Desc'].value_counts().head(30)
plt.figure(figsize=(12,6))
sns.barplot(top_30_crimes_southwest)
plt.xticks(rotation=45,ha='right')
plt.xlabel("Crimes")
plt.ylabel("Nombre de crimes")
plt.title("30 principeaux crimes dans 'Southwest'")
plt.show()

# %% [markdown]
# # 13

# %%
crime_count_2015_2016 = df[(df['DATE.OCC'].dt.year >= 2015) & (df['DATE.OCC'].dt.year <= 2016)]
sns.countplot(x = crime_count_2015_2016['DATE.OCC'].dt.year)
plt.title("Numbre d'incidents signales entre 2015 et 2016")
plt.xlabel('Year')
plt.ylabel("Numbre d'incidents")
plt.show()
